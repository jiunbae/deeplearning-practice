# %%
from models.fcn import FCN

# %%
model = FCN()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /home/jiun/.cache/torch/checkpoints/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [02:28<00:00, 3738788.46it/s]

# %%
from pathlib import Path

# %%
dset = list(sorted(Path('/home/jiun/datasets/VOC2012/JPEGImages').glob('*.jpg')))

# %%
images = dset[:32]

# %%
images[0]
# Out:
# PosixPath('/home/jiun/datasets/VOC2012/JPEGImages/2007_000027.jpg')

# %%
segments = list(map(lambda x: next(Path('/home/jiun/datasets/VOC2012/SegmentationClass').glob(f'{x.stem}.png')), images))

# %%
import cv2

# %%
img = cv2.imread(str(images[0]))

# %%
from IPython.display import display
from PIL import Image

# %%
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=486x500 at 0x7F1783528EB8>

# %%
dset = Path('/home/jiun/datasets/VOC2012/JPEGImages')
